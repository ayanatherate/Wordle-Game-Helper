# %%
import pandas as pd
import numpy as np
import random

# %%
data=pd.read_csv(r"C:\Users\User\Desktop\Wordle.txt")

# %%
#data=data[~data['which'].str.contains("s")]
data
# Out:
#       which
# 0     there
# 1     their
# 2     about
# 3     would
# 4     these
# ...     ...
# 5751  osier
# 5752  roble
# 5753  rumba
# 5754  biffy
# 5755  pupal
#
# [5756 rows x 1 columns]

# %%
word_list=[]
list_words=[]
data_words=[]
#data_words=[data['which'][i] for i in range(len(data))]
clean_data_words=[]


for i in range(len(data)):
    m=list(data['which'][i])
    for i in m:
        if not m[-1]=='s':
            data_words.append(m)


k=[]
for i in range(len(data)):
    m=list(data['which'][i])
    word_list.append(m)
    list_words.append(word_list)
    
for i in range(len(data_words)):
    word=''.join(data_words[i])
    if word in clean_data_words:
        pass
    else:
        clean_data_words.append(word)

# %%
go_first=random.choice(data_words)

go_first
# Out:
# ['s', 'h', 'o', 'c', 'k']

# %%
def wordle_game():
    
                
    go_first=random.choice(clean_data_words)
    print("let's start the game. You can start with this word  "+go_first)
    a=int(input(' 1 to continue, 0 to stop'))
    if a==1:
        print(guess_matches())

# %%
def input_letters():
    a1, b1=input("if you matched with something, type the letter and the position, space-separated").split(' ')
    a2,b2=input("For the machine's help, enter a word that did not match with anything (including position)")
    b1=int(b1)
    b2=input(b2)
    flag_str='s'
    for i in range(len(list_words)):
        for j in word_list[i]:
            if word_list[i][b1]==a1 and word_list[i][b2]!=a2:
                answer=''.join(word_list[i])
                if flag_str!=answer:
                    print("This is one suggestion we can provide. You should guess which one it is among these wisely!")
                    print(answer)
                    flag_str=answer

# %%
def guess_matches():
    t=[]
    final=0
    while final!=5:
        ans=input("Did you match with something? (Y/N)")
        if ans=='Y':
            print(input_letters())
            final+=1
        else:
            go_again=random.choice(clean_data_words)
            print("Here you can try again with this word "+go_again)
            continue
        if final==5:
            print("That's all the help I can provide you for now! You should guess yourself now else the game would be no fun!")
           
    
    
    
    #a2, b2=input("Did you match with anything else?If yes, then type the letter and the position in the same format. If not then write the same letter you matched with and the position, again please!").split(' ')
    #b2=int(b2)
    #a3, b3=input("For the machine's help")
    #flag_str='s'
    #for i in range(len(list_words)):
        #for j in word_list[i]:
            #if word_list[i][b1]==a1 and word_list[i][b2]==a2:
                #answer=''.join(word_list[i])
                #if flag_str!=answer:
                    #print(answer)
                    #flag_str=answer

# %%
wordle_game()
# Out:
# let's start the game. You can start with this word  avant
#  1 to continue, 0 to stop1
# Did you match with something? (Y/N)Y
# if you matched with something, type the letter and the position, space-separateda 2
# For the machine's help, enter a word that did not match with anything (including position)t 4
# This is one suggestion we can provide:
# years
# This is one suggestion we can provide:
# place
# This is one suggestion we can provide:
# again
# This is one suggestion we can provide:
# small
# This is one suggestion we can provide:
# shall
# This is one suggestion we can provide:
# heard
# This is one suggestion we can provide:
# means
# This is one suggestion we can provide:
# learn
# This is one suggestion we can provide:
# space
# This is one suggestion we can provide:
# state
# This is one suggestion we can provide:
# black
# This is one suggestion we can provide:
# heart
# This is one suggestion we can provide:
# ready
# This is one suggestion we can provide:
# class
# This is one suggestion we can provide:
# stand
# This is one suggestion we can provide:
# start
# This is one suggestion we can provide:
# least
# This is one suggestion we can provide:
# leave
# This is one suggestion we can provide:
# plant
# This is one suggestion we can provide:
# heavy
# This is one suggestion we can provide:
# plane
# This is one suggestion we can provide:
# glass
# This is one suggestion we can provide:
# death
# This is one suggestion we can provide:
# shape
# This is one suggestion we can provide:
# grass
# This is one suggestion we can provide:
# scale
# This is one suggestion we can provide:
# reach
# This is one suggestion we can provide:
# stars
# This is one suggestion we can provide:
# board
# This is one suggestion we can provide:
# trade
# This is one suggestion we can provide:
# meant
# This is one suggestion we can provide:
# train
# This is one suggestion we can provide:
# coast
# This is one suggestion we can provide:
# peace
# This is one suggestion we can provide:
# sharp
# This is one suggestion we can provide:
# stage
# This is one suggestion we can provide:
# plain
# This is one suggestion we can provide:
# apart
# This is one suggestion we can provide:
# chair
# This is one suggestion we can provide:
# heads
# This is one suggestion we can provide:
# share
# This is one suggestion we can provide:
# drawn
# This is one suggestion we can provide:
# piano
# This is one suggestion we can provide:
# boats
# This is one suggestion we can provide:
# plans
# This is one suggestion we can provide:
# roads
# This is one suggestion we can provide:
# chart
# This is one suggestion we can provide:
# graph
# This is one suggestion we can provide:
# grain
# This is one suggestion we can provide:
# plate
# This is one suggestion we can provide:
# plays
# This is one suggestion we can provide:
# thank
# This is one suggestion we can provide:
# brain
# This is one suggestion we can provide:
# track
# This is one suggestion we can provide:
# beach
# This is one suggestion we can provide:
# giant
# This is one suggestion we can provide:
# trail
# This is one suggestion we can provide:
# teach
# This is one suggestion we can provide:
# frame
# This is one suggestion we can provide:
# brave
# This is one suggestion we can provide:
# blank
# This is one suggestion we can provide:
# staff
# This is one suggestion we can provide:
# tears
# This is one suggestion we can provide:
# exact
# This is one suggestion we can provide:
# whale
# This is one suggestion we can provide:
# aware
# This is one suggestion we can provide:
# image
# This is one suggestion we can provide:
# snake
# This is one suggestion we can provide:
# chain
# This is one suggestion we can provide:
# shade
# This is one suggestion we can provide:
# claim
# This is one suggestion we can provide:
# guard
# This is one suggestion we can provide:
# bears
# This is one suggestion we can provide:
# brass
# This is one suggestion we can provide:
# beats
# This is one suggestion we can provide:
# beans
# This is one suggestion we can provide:
# grade
# This is one suggestion we can provide:
# slave
# This is one suggestion we can provide:
# flame
# This is one suggestion we can provide:
# trace
# This is one suggestion we can provide:
# seats
# This is one suggestion we can provide:
# leads
# This is one suggestion we can provide:
# meals
# This is one suggestion we can provide:
# shake
# This is one suggestion we can provide:
# teams
# This is one suggestion we can provide:
# crack
# This is one suggestion we can provide:
# coach
# This is one suggestion we can provide:
# awake
# This is one suggestion we can provide:
# feast
# This is one suggestion we can provide:
# blade
# This is one suggestion we can provide:
# reads
# This is one suggestion we can provide:
# claws
# This is one suggestion we can provide:
# beads
# This is one suggestion we can provide:
# beast
# This is one suggestion we can provide:
# grand
# This is one suggestion we can provide:
# drank
# This is one suggestion we can provide:
# shame
# This is one suggestion we can provide:
# flash
# This is one suggestion we can provide:
# weary
# This is one suggestion we can provide:
# coats
# This is one suggestion we can provide:
# spare
# This is one suggestion we can provide:
# alarm
# This is one suggestion we can provide:
# smart
# This is one suggestion we can provide:
# crash
# This is one suggestion we can provide:
# craft
# This is one suggestion we can provide:
# grace
# This is one suggestion we can provide:
# grave
# This is one suggestion we can provide:
# drama
# This is one suggestion we can provide:
# blame
# This is one suggestion we can provide:
# chalk
# This is one suggestion we can provide:
# crazy
# This is one suggestion we can provide:
# goats
# This is one suggestion we can provide:
# peaks
# This is one suggestion we can provide:
# beard
# This is one suggestion we can provide:
# stall
# This is one suggestion we can provide:
# stamp
# This is one suggestion we can provide:
# chase
# This is one suggestion we can provide:
# slant
# This is one suggestion we can provide:
# stays
# This is one suggestion we can provide:
# wrath
# This is one suggestion we can provide:
# shark
# This is one suggestion we can provide:
# grasp
# This is one suggestion we can provide:
# blast
# This is one suggestion we can provide:
# pearl
# This is one suggestion we can provide:
# loads
# This is one suggestion we can provide:
# hears
# This is one suggestion we can provide:
# phase
# This is one suggestion we can provide:
# toads
# This is one suggestion we can provide:
# seams
# This is one suggestion we can provide:
# quart
# This is one suggestion we can provide:
# fears
# This is one suggestion we can provide:
# spark
# This is one suggestion we can provide:
# goals
# This is one suggestion we can provide:
# grant
# This is one suggestion we can provide:
# shaft
# This is one suggestion we can provide:
# stare
# This is one suggestion we can provide:
# wears
# This is one suggestion we can provide:
# peach
# This is one suggestion we can provide:
# draft
# This is one suggestion we can provide:
# charm
# This is one suggestion we can provide:
# brake
# This is one suggestion we can provide:
# beams
# This is one suggestion we can provide:
# crawl
# This is one suggestion we can provide:
# toast
# This is one suggestion we can provide:
# brand
# This is one suggestion we can provide:
# stalk
# This is one suggestion we can provide:
# flags
# This is one suggestion we can provide:
# slain
# This is one suggestion we can provide:
# swamp
# This is one suggestion we can provide:
# diary
# This is one suggestion we can provide:
# flask
# This is one suggestion we can provide:
# stake
# This is one suggestion we can provide:
# draws
# This is one suggestion we can provide:
# deals
# This is one suggestion we can provide:
# dealt
# This is one suggestion we can provide:
# roast
# This is one suggestion we can provide:
# chant
# This is one suggestion we can provide:
# award
# This is one suggestion we can provide:
# drain
# This is one suggestion we can provide:
# meats
# This is one suggestion we can provide:
# usage
# This is one suggestion we can provide:
# scare
# This is one suggestion we can provide:
# traps
# This is one suggestion we can provide:
# react
# This is one suggestion we can provide:
# cease
# This is one suggestion we can provide:
# weave
# This is one suggestion we can provide:
# seals
# This is one suggestion we can provide:
# stack
# This is one suggestion we can provide:
# scarf
# This is one suggestion we can provide:
# coals
# This is one suggestion we can provide:
# loans
# This is one suggestion we can provide:
# flats
# This is one suggestion we can provide:
# clams
# This is one suggestion we can provide:
# yeast
# This is one suggestion we can provide:
# snail
# This is one suggestion we can provide:
# realm
# This is one suggestion we can provide:
# graze
# This is one suggestion we can provide:
# wharf
# This is one suggestion we can provide:
# slash
# This is one suggestion we can provide:
# clamp
# This is one suggestion we can provide:
# shack
# This is one suggestion we can provide:
# glare
# This is one suggestion we can provide:
# crane
# This is one suggestion we can provide:
# shawl
# This is one suggestion we can provide:
# tramp
# This is one suggestion we can provide:
# blaze
# This is one suggestion we can provide:
# crabs
# This is one suggestion we can provide:
# leaps
# This is one suggestion we can provide:
# snare
# This is one suggestion we can provide:
# plank
# This is one suggestion we can provide:
# brace
# This is one suggestion we can provide:
# scalp
# This is one suggestion we can provide:
# grams
# This is one suggestion we can provide:
# crank
# This is one suggestion we can provide:
# boast
# This is one suggestion we can provide:
# tract
# This is one suggestion we can provide:
# frail
# This is one suggestion we can provide:
# heats
# This is one suggestion we can provide:
# chaos
# This is one suggestion we can provide:
# lease
# This is one suggestion we can provide:
# gland
# This is one suggestion we can provide:
# skate
# This is one suggestion we can provide:
# snack
# This is one suggestion we can provide:
# tease
# This is one suggestion we can provide:
# shady
# This is one suggestion we can provide:
# leafy
# This is one suggestion we can provide:
# pears
# This is one suggestion we can provide:
# flaps
# This is one suggestion we can provide:
# adapt
# This is one suggestion we can provide:
# beaks
# This is one suggestion we can provide:
# trait
# This is one suggestion we can provide:
# ovary
# This is one suggestion we can provide:
# quack
# This is one suggestion we can provide:
# heaps
# This is one suggestion we can provide:
# slang
# This is one suggestion we can provide:
# await
# This is one suggestion we can provide:
# swarm
# This is one suggestion we can provide:
# frank
# This is one suggestion we can provide:
# snaps
# This is one suggestion we can provide:
# stain
# This is one suggestion we can provide:
# smash
# This is one suggestion we can provide:
# scary
# This is one suggestion we can provide:
# slabs
# This is one suggestion we can provide:
# jeans
# This is one suggestion we can provide:
# scars
# This is one suggestion we can provide:
# slate
# This is one suggestion we can provide:
# trays
# This is one suggestion we can provide:
# shaky
# This is one suggestion we can provide:
# crate
# This is one suggestion we can provide:
# heave
# This is one suggestion we can provide:
# gravy
# This is one suggestion we can provide:
# quail
# This is one suggestion we can provide:
# gears
# This is one suggestion we can provide:
# trash
# This is one suggestion we can provide:
# clash
# This is one suggestion we can provide:
# dwarf
# This is one suggestion we can provide:
# shave
# This is one suggestion we can provide:
# braid
# This is one suggestion we can provide:
# slack
# This is one suggestion we can provide:
# erase
# This is one suggestion we can provide:
# shale
# This is one suggestion we can provide:
# stair
# This is one suggestion we can provide:
# leans
# This is one suggestion we can provide:
# grape
# This is one suggestion we can provide:
# flank
# This is one suggestion we can provide:
# drags
# This is one suggestion we can provide:
# roars
# This is one suggestion we can provide:
# feats
# This is one suggestion we can provide:
# exalt
# This is one suggestion we can provide:
# leash
# This is one suggestion we can provide:
# llama
# This is one suggestion we can provide:
# stale
# This is one suggestion we can provide:
# leaks
# This is one suggestion we can provide:
# snarl
# This is one suggestion we can provide:
# flare
# This is one suggestion we can provide:
# soaks
# This is one suggestion we can provide:
# plaid
# This is one suggestion we can provide:
# swans
# This is one suggestion we can provide:
# chaps
# This is one suggestion we can provide:
# stark
# This is one suggestion we can provide:
# shank
# This is one suggestion we can provide:
# scant
# This is one suggestion we can provide:
# grabs
# This is one suggestion we can provide:
# leapt
# This is one suggestion we can provide:
# soaps
# This is one suggestion we can provide:
# wraps
# This is one suggestion we can provide:
# fraud
# This is one suggestion we can provide:
# psalm
# This is one suggestion we can provide:
# whack
# This is one suggestion we can provide:
# clasp
# This is one suggestion we can provide:
# champ
# This is one suggestion we can provide:
# quake
# This is one suggestion we can provide:
# knack
# This is one suggestion we can provide:
# plaza
# This is one suggestion we can provide:
# cramp
# This is one suggestion we can provide:
# roach
# This is one suggestion we can provide:
# bland
# This is one suggestion we can provide:
# dials
# This is one suggestion we can provide:
# slaps
# This is one suggestion we can provide:
# foams
# This is one suggestion we can provide:
# gnats
# This is one suggestion we can provide:
# leaky
# This is one suggestion we can provide:
# spans
# This is one suggestion we can provide:
# glaze
# This is one suggestion we can provide:
# trawl
# This is one suggestion we can provide:
# claps
# This is one suggestion we can provide:
# clang
# This is one suggestion we can provide:
# spade
# This is one suggestion we can provide:
# flaky
# This is one suggestion we can provide:
# spars
# This is one suggestion we can provide:
# scaly
# This is one suggestion we can provide:
# grate
# This is one suggestion we can provide:
# flaws
# This is one suggestion we can provide:
# flake
# This is one suggestion we can provide:
# snags
# This is one suggestion we can provide:
# drawl
# This is one suggestion we can provide:
# soapy
# This is one suggestion we can provide:
# crags
# This is one suggestion we can provide:
# twang
# This is one suggestion we can provide:
# spawn
# This is one suggestion we can provide:
# spasm
# This is one suggestion we can provide:
# exams
# This is one suggestion we can provide:
# enact
# This is one suggestion we can provide:
# nears
# This is one suggestion we can provide:
# flair
# This is one suggestion we can provide:
# prays
# This is one suggestion we can provide:
# stave
# This is one suggestion we can provide:
# khaki
# This is one suggestion we can provide:
# loath
# This is one suggestion we can provide:
# slats
# This is one suggestion we can provide:
# flail
# This is one suggestion we can provide:
# clays
# This is one suggestion we can provide:
# thaws
# This is one suggestion we can provide:
# twain
# This is one suggestion we can provide:
# scamp
# This is one suggestion we can provide:
# bravo
# This is one suggestion we can provide:
# glade
# This is one suggestion we can provide:
# heath
# This is one suggestion we can provide:
# evade
# This is one suggestion we can provide:
# slams
# This is one suggestion we can provide:
# clank
# This is one suggestion we can provide:
# graft
# This is one suggestion we can provide:
# chaff
# This is one suggestion we can provide:
# scans
# This is one suggestion we can provide:
# hoary
# This is one suggestion we can provide:
# franc
# This is one suggestion we can provide:
# liars
# This is one suggestion we can provide:
# soars
# This is one suggestion we can provide:
# yearn
# This is one suggestion we can provide:
# ovals
# This is one suggestion we can provide:
# heals
# This is one suggestion we can provide:
# blare
# This is one suggestion we can provide:
# moans
# This is one suggestion we can provide:
# adage
# This is one suggestion we can provide:
# stabs
# This is one suggestion we can provide:
# foals
# This is one suggestion we can provide:
# aback
# This is one suggestion we can provide:
# hoard
# This is one suggestion we can provide:
# craze
# This is one suggestion we can provide:
# shalt
# This is one suggestion we can provide:
# grays
# This is one suggestion we can provide:
# reams
# This is one suggestion we can provide:
# spank
# This is one suggestion we can provide:
# opals
# This is one suggestion we can provide:
# brawl
# This is one suggestion we can provide:
# brags
# This is one suggestion we can provide:
# chasm
# This is one suggestion we can provide:
# koala
# This is one suggestion we can provide:
# quays
# This is one suggestion we can provide:
# meaty
# This is one suggestion we can provide:
# amaze
# This is one suggestion we can provide:
# clans
# This is one suggestion we can provide:
# gnaws
# This is one suggestion we can provide:
# agate
# This is one suggestion we can provide:
# amass
# This is one suggestion we can provide:
# crave
# This is one suggestion we can provide:
# knave
# This is one suggestion we can provide:
# dears
# This is one suggestion we can provide:
# irate
# This is one suggestion we can provide:
# stags
# This is one suggestion we can provide:
# scabs
# This is one suggestion we can provide:
# sways
# This is one suggestion we can provide:
# slays
# This is one suggestion we can provide:
# boars
# This is one suggestion we can provide:
# gnash
# This is one suggestion we can provide:
# brawn
# This is one suggestion we can provide:
# drape
# This is one suggestion we can provide:
# tiara
# This is one suggestion we can provide:
# brats
# This is one suggestion we can provide:
# tsars
# This is one suggestion we can provide:
# frays
# This is one suggestion we can provide:
# stank
# This is one suggestion we can provide:
# scald
# This is one suggestion we can provide:
# peals
# This is one suggestion we can provide:
# roams
# This is one suggestion we can provide:
# spats
# This is one suggestion we can provide:
# abate
# This is one suggestion we can provide:
# moats
# This is one suggestion we can provide:
# mealy
# This is one suggestion we can provide:
# slake
# This is one suggestion we can provide:
# brays
# This is one suggestion we can provide:
# chats
# This is one suggestion we can provide:
# inane
# This is one suggestion we can provide:
# vials
# This is one suggestion we can provide:
# slags
# This is one suggestion we can provide:
# plait
# This is one suggestion we can provide:
# chafe
# This is one suggestion we can provide:
# czars
# This is one suggestion we can provide:
# snaky
# This is one suggestion we can provide:
# swaps
# This is one suggestion we can provide:
# poach
# This is one suggestion we can provide:
# prank
# This is one suggestion we can provide:
# goads
# This is one suggestion we can provide:
# shams
# This is one suggestion we can provide:
# quaff
# This is one suggestion we can provide:
# deans
# This is one suggestion we can provide:
# reaps
# This is one suggestion we can provide:
# rears
# This is one suggestion we can provide:
# loams
# This is one suggestion we can provide:
# leafs
# This is one suggestion we can provide:
# scads
# This is one suggestion we can provide:
# qualm
# This is one suggestion we can provide:
# crams
# This is one suggestion we can provide:
# flays
# This is one suggestion we can provide:
# leach
# This is one suggestion we can provide:
# loafs
# This is one suggestion we can provide:
# deads
# This is one suggestion we can provide:
# beaus
# This is one suggestion we can provide:
# zeals
# This is one suggestion we can provide:
# okays
# This is one suggestion we can provide:
# brans
# This is one suggestion we can provide:
# teals
# This is one suggestion we can provide:
# swats
# This is one suggestion we can provide:
# veals
# This is one suggestion we can provide:
# swabs
# This is one suggestion we can provide:
# okapi
# This is one suggestion we can provide:
# sears
# This is one suggestion we can provide:
# weans
# This is one suggestion we can provide:
# meany
# This is one suggestion we can provide:
# drake
# This is one suggestion we can provide:
# smack
# This is one suggestion we can provide:
# avail
# This is one suggestion we can provide:
# beady
# This is one suggestion we can provide:
# leant
# This is one suggestion we can provide:
# trans
# This is one suggestion we can provide:
# foamy
# This is one suggestion we can provide:
# alack
# This is one suggestion we can provide:
# spake
# This is one suggestion we can provide:
# avant
# This is one suggestion we can provide:
# trams
# This is one suggestion we can provide:
# heady
# This is one suggestion we can provide:
# brash
# This is one suggestion we can provide:
# swash
# This is one suggestion we can provide:
# awash
# This is one suggestion we can provide:
# apace
# This is one suggestion we can provide:
# staid
# This is one suggestion we can provide:
# swath
# This is one suggestion we can provide:
# spate
# This is one suggestion we can provide:
# deary
# This is one suggestion we can provide:
# agave
# This is one suggestion we can provide:
# brads
# This is one suggestion we can provide:
# suave
# This is one suggestion we can provide:
# imams
# This is one suggestion we can provide:
# aways
# This is one suggestion we can provide:
# wrack
# This is one suggestion we can provide:
# quads
# This is one suggestion we can provide:
# clack
# This is one suggestion we can provide:
# unary
# This is one suggestion we can provide:
# swank
# This is one suggestion we can provide:
# loamy
# This is one suggestion we can provide:
# reals
# This is one suggestion we can provide:
# abaci
# This is one suggestion we can provide:
# grads
# This is one suggestion we can provide:
# sward
# This is one suggestion we can provide:
# coati
# This is one suggestion we can provide:
# braze
# This is one suggestion we can provide:
# peaty
# This is one suggestion we can provide:
# beaut
# This is one suggestion we can provide:
# crass
# This is one suggestion we can provide:
# hoagy
# This is one suggestion we can provide:
# swain
# This is one suggestion we can provide:
# abase
# This is one suggestion we can provide:
# kraut
# This is one suggestion we can provide:
# guava
# This is one suggestion we can provide:
# scarp
# This is one suggestion we can provide:
# prams
# This is one suggestion we can provide:
# clave
# This is one suggestion we can provide:
# rearm
# This is one suggestion we can provide:
# avast
# This is one suggestion we can provide:
# swami
# This is one suggestion we can provide:
# quasi
# This is one suggestion we can provide:
# peaky
# This is one suggestion we can provide:
# seamy
# This is one suggestion we can provide:
# chary
# This is one suggestion we can provide:
# khans
# This is one suggestion we can provide:
# blabs
# This is one suggestion we can provide:
# quash
# This is one suggestion we can provide:
# quals
# This is one suggestion we can provide:
# spacy
# This is one suggestion we can provide:
# chard
# This is one suggestion we can provide:
# whang
# This is one suggestion we can provide:
# frats
# This is one suggestion we can provide:
# neato
# This is one suggestion we can provide:
# epact
# This is one suggestion we can provide:
# ikats
# This is one suggestion we can provide:
# chaws
# This is one suggestion we can provide:
# thane
# This is one suggestion we can provide:
# tzars
# This is one suggestion we can provide:
# phage
# This is one suggestion we can provide:
# fiats
# This is one suggestion we can provide:
# roans
# This is one suggestion we can provide:
# abash
# This is one suggestion we can provide:
# shahs
# This is one suggestion we can provide:
# shard
# This is one suggestion we can provide:
# craps
# This is one suggestion we can provide:
# shags
# This is one suggestion we can provide:
# drams
# This is one suggestion we can provide:
# gnarl
# This is one suggestion we can provide:
# grail
# This is one suggestion we can provide:
# quark
# This is one suggestion we can provide:
# prate
# This is one suggestion we can provide:
# stash
# This is one suggestion we can provide:
# whams
# This is one suggestion we can provide:
# spays
# This is one suggestion we can provide:
# swart
# This is one suggestion we can provide:
# egads
# This is one suggestion we can provide:
# clads
# This is one suggestion we can provide:
# scams
# This is one suggestion we can provide:
# blats
# This is one suggestion we can provide:
# viand
# This is one suggestion we can provide:
# snafu
# This is one suggestion we can provide:
# craws
# This is one suggestion we can provide:
# stats
# This is one suggestion we can provide:
# prawn
# This is one suggestion we can provide:
# luaus
# This is one suggestion we can provide:
# toady
# This is one suggestion we can provide:
# duals
# This is one suggestion we can provide:
# drays
# This is one suggestion we can provide:
# flack
# This is one suggestion we can provide:
# staph
# This is one suggestion we can provide:
# blahs
# This is one suggestion we can provide:
# orals
# This is one suggestion we can provide:
# elate
# This is one suggestion we can provide:
# quais
# This is one suggestion we can provide:
# agape
# This is one suggestion we can provide:
# dyads
# This is one suggestion we can provide:
# teats
# This is one suggestion we can provide:
# thats
# This is one suggestion we can provide:
# abaca
# This is one suggestion we can provide:
# plasm
# This is one suggestion we can provide:
# shads
# This is one suggestion we can provide:
# flams
# This is one suggestion we can provide:
# thanx
# This is one suggestion we can provide:
# plats
# This is one suggestion we can provide:
# amahs
# This is one suggestion we can provide:
# mrads
# This is one suggestion we can provide:
# grata
# This is one suggestion we can provide:
# teary
# This is one suggestion we can provide:
# inapt
# This is one suggestion we can provide:
# ukase
# This is one suggestion we can provide:
# beaux
# This is one suggestion we can provide:
# orate
# This is one suggestion we can provide:
# neath
# This is one suggestion we can provide:
# beaky
# This is one suggestion we can provide:
# tuans
# This is one suggestion we can provide:
# blash
# This is one suggestion we can provide:
# swarf
# This is one suggestion we can provide:
# brack
# This is one suggestion we can provide:
# imago
# This is one suggestion we can provide:
# kraal
# This is one suggestion we can provide:
# chars
# This is one suggestion we can provide:
# hoars
# This is one suggestion we can provide:
# shays
# This is one suggestion we can provide:
# plash
# This is one suggestion we can provide:
# agars
# This is one suggestion we can provide:
# brant
# This is one suggestion we can provide:
# drabs
# This is one suggestion we can provide:
# ovate
# This is one suggestion we can provide:
# shawm
# This is one suggestion we can provide:
# braes
# This is one suggestion we can provide:
# diazo
# This is one suggestion we can provide:
# unapt
# This is one suggestion we can provide:
# glads
# This is one suggestion we can provide:
# spazz
# This is one suggestion we can provide:
# shako
# This is one suggestion we can provide:
# unarm
# This is one suggestion we can provide:
# flaks
# This is one suggestion we can provide:
# guano
# This is one suggestion we can provide:
# bwana
# This is one suggestion we can provide:
# spang
# This is one suggestion we can provide:
# grapy
# This is one suggestion we can provide:
# flabs
# This is one suggestion we can provide:
# slaws
# This is one suggestion we can provide:
# meads
# This is one suggestion we can provide:
# email
# This is one suggestion we can provide:
# stagy
# This is one suggestion we can provide:
# asana
# This is one suggestion we can provide:
# brava
# This is one suggestion we can provide:
# unate
# This is one suggestion we can provide:
# weals
# This is one suggestion we can provide:
# miaow
# This is one suggestion we can provide:
# scats
# This is one suggestion we can provide:
# glans
# This is one suggestion we can provide:
# glary
# This is one suggestion we can provide:
# beamy
# This is one suggestion we can provide:
# weald
# This is one suggestion we can provide:
# teaks
# This is one suggestion we can provide:
# prats
# This is one suggestion we can provide:
# bhang
# This is one suggestion we can provide:
# pease
# This is one suggestion we can provide:
# whats
# This is one suggestion we can provide:
# snarf
# This is one suggestion we can provide:
# sware
# This is one suggestion we can provide:
# elans
# This is one suggestion we can provide:
# snark
# This is one suggestion we can provide:
# beano
# This is one suggestion we can provide:
# bract
# This is one suggestion we can provide:
# playa
# This is one suggestion we can provide:
# rials
# This is one suggestion we can provide:
# swags
# This is one suggestion we can provide:
# twats
# This is one suggestion we can provide:
# abaft
# This is one suggestion we can provide:
# peats
# This is one suggestion we can provide:
# unarc
# This is one suggestion we can provide:
# eland
# None
# Did you match with something? (Y/N)Y
# if you matched with something, type the letter and the position, space-separatedY
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17468/1593636835.py in <module>
# ----> 1 wordle_game()
#
# ~\AppData\Local\Temp/ipykernel_17468/479937733.py in wordle_game()
#       6     a=int(input(' 1 to continue, 0 to stop'))
#       7     if a==1:
# ----> 8         print(guess_matches())
#       9
#      10
#
# ~\AppData\Local\Temp/ipykernel_17468/3437123660.py in guess_matches()
#       5         ans=input("Did you match with something? (Y/N)")
#       6         if ans=='Y':
# ----> 7             print(input_letters())
#       8             final+=1
#       9         else:
#
# ~\AppData\Local\Temp/ipykernel_17468/3544374352.py in input_letters()
#       1 def input_letters():
# ----> 2     a1, b1=input("if you matched with something, type the letter and the position, space-separated").split(' ')
#       3     a2=input("For the machine's help, enter a word that did not match with anything (including position)")
#       4     b1=int(b1)
#       5     flag_str='s'
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
flag_str='s'
for i in range(len(list_words)):
        for j in word_list[i]:
            if word_list[i][2]=='o' and word_list[i][3]=='t':
                answer=''.join(word_list[i])
                if flag_str!=answer:
                    print("This is one suggestion we can provide:")
                    print(answer)
                    flag_str=answer
# Out:
# This is one suggestion we can provide:
# wrote
# This is one suggestion we can provide:
# roots
# This is one suggestion we can provide:
# cloth
# This is one suggestion we can provide:
# boots
# This is one suggestion we can provide:
# spots
# This is one suggestion we can provide:
# shots
# This is one suggestion we can provide:
# tooth
# This is one suggestion we can provide:
# knots
# This is one suggestion we can provide:
# photo
# This is one suggestion we can provide:
# quote
# This is one suggestion we can provide:
# booth
# This is one suggestion we can provide:
# smote
# This is one suggestion we can provide:
# plots
# This is one suggestion we can provide:
# broth
# This is one suggestion we can provide:
# slots
# This is one suggestion we can provide:
# sloth
# This is one suggestion we can provide:
# riots
# This is one suggestion we can provide:
# quota
# This is one suggestion we can provide:
# booty
# This is one suggestion we can provide:
# trots
# This is one suggestion we can provide:
# froth
# This is one suggestion we can provide:
# toots
# This is one suggestion we can provide:
# clots
# This is one suggestion we can provide:
# blots
# This is one suggestion we can provide:
# hoots
# This is one suggestion we can provide:
# loots
# This is one suggestion we can provide:
# soots
# This is one suggestion we can provide:
# quoth
# This is one suggestion we can provide:
# sooty
# This is one suggestion we can provide:
# troth
# This is one suggestion we can provide:
# coots
# This is one suggestion we can provide:
# sooth
# This is one suggestion we can provide:
# emote
# This is one suggestion we can provide:
# snots
# This is one suggestion we can provide:
# foots
# This is one suggestion we can provide:
# wroth
# This is one suggestion we can provide:
# rooty
# This is one suggestion we can provide:
# zloty
# This is one suggestion we can provide:
# ghoti
# This is one suggestion we can provide:
# moots
